# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
File="./Data/personality_dataset.csv"
df=pd.read_csv(File)

# %%
df.head()
# Out:
#    Time_spent_Alone Stage_fear  Social_event_attendance  Going_outside  \
# 0               4.0         No                      4.0            6.0
# 1               9.0        Yes                      0.0            0.0
# 2               9.0        Yes                      1.0            2.0
# 3               0.0         No                      6.0            7.0
# 4               3.0         No                      9.0            4.0
#
#   Drained_after_socializing  Friends_circle_size  Post_frequency Personality
# 0                        No                 13.0             5.0   Extrovert
# 1                       Yes                  0.0             3.0   Introvert
# 2                       Yes                  5.0             2.0   Introvert
# 3                        No                 14.0             8.0   Extrovert
# 4                        No                  8.0             5.0   Extrovert

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df[df["Time_spent_Alone"].isnull()]
# Out:
#       Time_spent_Alone Stage_fear  Social_event_attendance  Going_outside  \
# 59                 NaN         No                      9.0            4.0
# 125                NaN        Yes                      3.0            0.0
# 171                NaN         No                      4.0            7.0
# 180                NaN         No                      8.0            5.0
# 207                NaN        Yes                      2.0            2.0
# ...                ...        ...                      ...            ...
# 2705               NaN         No                      9.0            5.0
# 2711               NaN         No                      4.0            6.0
# 2715               NaN         No                      6.0            6.0
# 2772               NaN         No                      7.0            6.0
# 2787               NaN        NaN                      1.0            2.0
#
#      Drained_after_socializing  Friends_circle_size  Post_frequency  \
# ...

# %%
df[(df["Stage_fear"].isnull()) ]
# Out:
#       Time_spent_Alone Stage_fear  Social_event_attendance  Going_outside  \
# 115                4.0        NaN                      5.0            5.0
# 157                2.0        NaN                      6.0            7.0
# 205                8.0        NaN                      0.0            NaN
# 225                6.0        NaN                      0.0            2.0
# 282                9.0        NaN                      1.0            1.0
# ...                ...        ...                      ...            ...
# 2753               0.0        NaN                      4.0            5.0
# 2787               NaN        NaN                      1.0            2.0
# 2842               2.0        NaN                      8.0            5.0
# 2882               1.0        NaN                      9.0            3.0
# 2893               9.0        NaN                      2.0            0.0
#
#      Drained_after_socializing  Friends_circle_size  Post_frequency  \
# ...

# %%
df[["Stage_fear","Personality"]]
# Out:
#      Stage_fear Personality
# 0            No   Extrovert
# 1           Yes   Introvert
# 2           Yes   Introvert
# 3            No   Extrovert
# 4            No   Extrovert
# ...         ...         ...
# 2895         No   Extrovert
# 2896         No   Extrovert
# 2897        Yes   Introvert
# 2898        Yes   Introvert
# 2899         No   Extrovert
#
# [2900 rows x 2 columns]

# %%
df.loc[df["Stage_fear"].isnull(), "Stage_fear"] = [
    "Yes" if value == "Introvert" else "No"
    for value in df.loc[df["Stage_fear"].isnull(), "Personality"]
]

# %%
df["Stage_fear"].head(150)
# Out:
# 0       No
# 1      Yes
# 2      Yes
# 3       No
# 4       No
#       ...
# 145     No
# 146    Yes
# 147    Yes
# 148     No
# 149     No
# Name: Stage_fear, Length: 150, dtype: object

# %%
import random

mask = df["Social_event_attendance"].isnull()
df.loc[mask, "Social_event_attendance"] = [random.randint(0, 3) for _ in range(mask.sum())]

# %%
df[(df["Personality"]=="Introvert")]["Social_event_attendance"].value_counts().plot(kind="bar",xlabel="No of events",ylabel="No of People")
# Out:
# <Axes: xlabel='No of events', ylabel='No of People'>

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df[df["Going_outside"].isnull()].head(30)
# Out:
#       Time_spent_Alone Stage_fear  Social_event_attendance  Going_outside  \
# 6                  4.0         No                      9.0            NaN
# 96                 1.0         No                      5.0            NaN
# 199                3.0         No                      6.0            NaN
# 205                8.0        Yes                      0.0            NaN
# 274                5.0        Yes                      1.0            NaN
# 310                1.0         No                      4.0            NaN
# 311                0.0         No                      6.0            NaN
# 604               10.0        Yes                      3.0            NaN
# 647                6.0        Yes                      2.0            NaN
# 670                0.0         No                      4.0            NaN
# 674               10.0        Yes                      0.0            NaN
# 734                0.0         No                      5.0            NaN
# ...

# %%
df["Going_outside"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Going_outside'>

# %%
intro=df[df["Personality"]=="Introvert"]["Going_outside"].value_counts().plot(kind="bar")
extro=df[df["Personality"]=="Extrovert"]["Going_outside"].value_counts(ascending=True).plot(kind="bar",width=0.9,color="red",alpha=0.5)

# %%
import random

mask = df["Going_outside"].isnull()
df.loc[mask, "Going_outside"] = [random.randint(0, 2) for _ in range(mask.sum())]

# %%
df[df["Drained_after_socializing"].isnull()]
# Out:
#       Time_spent_Alone Stage_fear  Social_event_attendance  Going_outside  \
# 33                 8.0        Yes                      3.0            3.0
# 83                 7.0        Yes                      1.0            0.0
# 230                8.0        Yes                      2.0            2.0
# 368                1.0         No                      5.0            6.0
# 424                1.0         No                      4.0            7.0
# 611                3.0         No                      4.0            7.0
# 765                0.0         No                      6.0            4.0
# 768               10.0        Yes                      1.0            2.0
# 906                5.0        Yes                      3.0            0.0
# 1018               NaN         No                      7.0            5.0
# 1280               4.0        Yes                      2.0            1.0
# 1421               5.0        Yes                      0.0            2.0
# ...

# %%
df["Drained_after_socializing"].value_counts()
# Out:
# Drained_after_socializing
# No     1441
# Yes    1407
# Name: count, dtype: int64

# %%
df[df["Personality"]=="Introvert"]["Drained_after_socializing"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Drained_after_socializing'>

# %%
df[df["Personality"]=="Extrovert"]["Drained_after_socializing"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Drained_after_socializing'>

# %%
df.loc[df["Drained_after_socializing"].isnull(),"Drained_after_socializing"]=["Yes" if value=="Introvert" else "No" for value in df.loc[df["Drained_after_socializing"].isnull(),"Personality"]]

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df[df["Personality"]=="Extrovert"]["Post_frequency"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Post_frequency'>

# %%
df[df["Personality"]=="Introvert"]["Post_frequency"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Post_frequency'>

# %%
df[df["Post_frequency"].isnull()]["Personality"].value_counts()
# Out:
# Personality
# Extrovert    33
# Introvert    32
# Name: count, dtype: int64

# %%
mean_post_fre_intro=np.floor(df[(~df["Post_frequency"].isnull()) & (df["Personality"]=="Introvert")]["Post_frequency"].mean())
mean_post_fre_extro=np.floor(df[(~df["Post_frequency"].isnull()) & (df["Personality"]=="Extrovert")]["Post_frequency"].mean())

# %%
print(mean_post_fre_intro,mean_post_fre_extro)
# Out:
# 1.0 5.0

# %%
df.loc[df["Post_frequency"].isnull(),"Post_frequency"]=[mean_post_fre_extro if value=="Extrovert" else mean_post_fre_intro for value in df.loc[df["Post_frequency"].isnull(),"Personality"]]

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df[df["Personality"]=="Extrovert"]["Friends_circle_size"].value_counts().sort_index().plot(kind="bar")
# Out:
# <Axes: xlabel='Friends_circle_size'>

# %%
df[df["Personality"]=="Introvert"]["Friends_circle_size"].value_counts().sort_index().plot(kind="bar")
# Out:
# <Axes: xlabel='Friends_circle_size'>

# %%
df[df["Personality"]=="Introvert"]["Friends_circle_size"].isnull().value_counts()
# Out:
# Friends_circle_size
# False    1372
# True       37
# Name: count, dtype: int64

# %%
df[df["Personality"]=="Extrovert"]["Friends_circle_size"].isnull().value_counts()
# Out:
# Friends_circle_size
# False    1451
# True       40
# Name: count, dtype: int64

# %%
mean_of_intro_fc=np.floor(df[df["Personality"]=="Introvert"]["Friends_circle_size"].mean())
mean_of_extro_fc=np.floor(df[df["Personality"]=="Extrovert"]["Friends_circle_size"].mean())
print(mean_of_extro_fc,mean_of_intro_fc)
# Out:
# 9.0 3.0

# %%
mask = df["Friends_circle_size"].isnull()

df.loc[mask, "Friends_circle_size"] = [
    mean_of_intro_fc if value == "Introvert" else mean_of_extro_fc
    for value in df.loc[mask, "Personality"]
]

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df[df["Personality"]=="Introvert"]["Time_spent_Alone"].value_counts()
# Out:
# Time_spent_Alone
# 9.0     190
# 10.0    177
# 5.0     177
# 7.0     173
# 4.0     163
# 8.0     161
# 6.0     142
# 11.0    119
# 2.0      29
# 0.0      23
# 1.0      21
# 3.0       5
# Name: count, dtype: int64

# %%
df[df["Personality"]=="Extrovert"]["Time_spent_Alone"].value_counts()
# Out:
# Time_spent_Alone
# 3.0     348
# 0.0     346
# 2.0     328
# 1.0     305
# 4.0      27
# 11.0     21
# 10.0     19
# 8.0      19
# 7.0      17
# 9.0      16
# 6.0       8
# 5.0       3
# Name: count, dtype: int64

# %%
mean_of_intro_ts=np.floor(df[df["Personality"]=="Introvert"]["Time_spent_Alone"].mean())
mean_of_extro_ts=np.floor(df[df["Personality"]=="Extrovert"]["Time_spent_Alone"].mean())
print(mean_of_extro_ts,mean_of_intro_ts)
# Out:
# 2.0 7.0

# %%
mask = df["Time_spent_Alone"].isnull()

df.loc[mask, "Time_spent_Alone"] = [
    mean_of_intro_fc if value == "Introvert" else mean_of_extro_fc
    for value in df.loc[mask, "Personality"]
]

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2900 entries, 0 to 2899
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Time_spent_Alone           2900 non-null   float64
#  1   Stage_fear                 2900 non-null   object
#  2   Social_event_attendance    2900 non-null   float64
#  3   Going_outside              2900 non-null   float64
#  4   Drained_after_socializing  2900 non-null   object
#  5   Friends_circle_size        2900 non-null   float64
#  6   Post_frequency             2900 non-null   float64
#  7   Personality                2900 non-null   object
# dtypes: float64(5), object(3)
# memory usage: 181.4+ KB

# %%
df["Stage_fear"]=[1 if value=="Yes" else 0 for value in df["Stage_fear"]]
df["Drained_after_socializing"]=[1 if value=="Yes" else 0 for value in df["Drained_after_socializing"]]
df["Personality"]=[1 if value=="Introvert" else 0 for value in df["Personality"]]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2900 entries, 0 to 2899
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Time_spent_Alone           2900 non-null   float64
#  1   Stage_fear                 2900 non-null   int64
#  2   Social_event_attendance    2900 non-null   float64
#  3   Going_outside              2900 non-null   float64
#  4   Drained_after_socializing  2900 non-null   int64
#  5   Friends_circle_size        2900 non-null   float64
#  6   Post_frequency             2900 non-null   float64
#  7   Personality                2900 non-null   int64
# dtypes: float64(5), int64(3)
# memory usage: 181.4 KB

# %%
df["Personality"].value_counts()
# Out:
# Personality
# 0    1491
# 1    1409
# Name: count, dtype: int64

# %%
y=df["Personality"]
X=df.drop("Personality",axis=1)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_scaled=scaler.fit_transform(X)

# %%
plt.hist(X_scaled,bins=10)
# Out:
# (array([[ 369.,  326.,  739.,  190.,  180.,  340.,  180.,  240.,  196.,
#           140.],
#         [   0., 1459.,    0.,    0.,    0.,    0., 1441.,    0.,    0.,
#             0.],
#         [ 390.,  340.,  426.,  331.,  255.,  463.,  239.,  206.,  236.,
#            14.],
#         [ 525.,  449.,  475.,    0.,  209.,  359.,  374.,  335.,  174.,
#             0.],
#         [   0., 1459.,    0.,    0.,    0.,    0., 1441.,    0.,    0.,
#             0.],
#         [ 387.,  594.,  254.,  438.,  133.,  340.,  146.,  282.,  267.,
#            59.],
#         [ 451.,  487.,  481.,  208.,  195.,  245.,  210.,  236.,  193.,
#           194.]]),
#  array([-1.47069264, -1.10203909, -0.73338553, -0.36473197,  0.00392159,
#          0.37257515,  0.7412287 ,  1.10988226,  1.47853582,  1.84718938,
#          2.21584294]),
#  <a list of 7 BarContainer objects>)

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test=train_test_split(X_scaled,y,test_size=0.3,random_state=42)

# %%
print(y_train.unique())
print(y_train.value_counts())
# Out:
# [0 1]
# Personality
# 0    1028
# 1    1002
# Name: count, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

accuracy_s=accuracy_score(y_test,y_pred)

# %%
print(accuracy_s*100
      )
# Out:
# 92.64367816091954

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.92      0.93       463
#            1       0.91      0.93      0.92       407
#
#     accuracy                           0.93       870
#    macro avg       0.93      0.93      0.93       870
# weighted avg       0.93      0.93      0.93       870

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2900 entries, 0 to 2899
# Data columns (total 8 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Time_spent_Alone           2900 non-null   float64
#  1   Stage_fear                 2900 non-null   int64
#  2   Social_event_attendance    2900 non-null   float64
#  3   Going_outside              2900 non-null   float64
#  4   Drained_after_socializing  2900 non-null   int64
#  5   Friends_circle_size        2900 non-null   float64
#  6   Post_frequency             2900 non-null   float64
#  7   Personality                2900 non-null   int64
# dtypes: float64(5), int64(3)
# memory usage: 181.4 KB

# %%
y_pred=model.predict([[3,1,3,6,1,3,1]])

# %%
print(accuracy_score([1],y_pred))
# Out:
# 1.0

# %%
df.head()
# Out:
#    Time_spent_Alone  Stage_fear  Social_event_attendance  Going_outside  \
# 0               4.0           0                      4.0            6.0
# 1               9.0           1                      0.0            0.0
# 2               9.0           1                      1.0            2.0
# 3               0.0           0                      6.0            7.0
# 4               3.0           0                      9.0            4.0
#
#    Drained_after_socializing  Friends_circle_size  Post_frequency  Personality
# 0                          0                 13.0             5.0            0
# 1                          1                  0.0             3.0            1
# 2                          1                  5.0             2.0            1
# 3                          0                 14.0             8.0            0
# 4                          0                  8.0             5.0            0

# %%
vals=df[df["Personality"]==1]["Friends_circle_size"]

# %%
print(vals)
# Out:
# 1       0.0
# 2       5.0
# 8       0.0
# 11      4.0
# 14      1.0
#        ...
# 2891    5.0
# 2892    1.0
# 2893    4.0
# 2897    4.0
# 2898    2.0
# Name: Friends_circle_size, Length: 1409, dtype: float64

# %%
plt.scatter(vals.index,vals.values)

# %%
df["Friends_circle_size"].isnull().sum()
# Out:
# np.int64(0)

# %%
vals=df["Friends_circle_size"]
scaled_vals=scaler.fit_transform(vals.values.reshape(-1,1))

# %%
plt.hist(scaled_vals,bins=10)
# Out:
# (array([387., 594., 254., 438., 133., 165., 321., 134., 271., 203.]),
#  array([-1.47069264, -1.11856181, -0.76643097, -0.41430014, -0.06216931,
#          0.28996153,  0.64209236,  0.9942232 ,  1.34635403,  1.69848487,
#          2.0506157 ]),
#  <BarContainer object of 10 artists>)

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.to_csv("./Data/Removed_null_personality_dataset.csv")

# %% [markdown]
# Optimization

# %%
log_model=LogisticRegression(max_iter=10000)

# %%
log_model.fit(X_train, y_train)
y_pred = log_model.predict(X_test)  # Predict on the features of test set
acc = accuracy_score(y_test, y_pred)  # Compare with actual test labels
print("Accuracy:", acc)
# Out:
# Accuracy: 0.9264367816091954

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X_data=np.random.random(500)*100
Y_data=np.random.random(500)*100
plt.scatter(X_data,Y_data,c="red",marker="*",alpha=0.2)

# %%
years=[2006+ x for x in range(5)]
weights=[80,83,84,90,81]

# %%
plt.plot(years,weights,"r--")

# %%
x=["Python","Java","C++","C","Javascript"]
y=[15,8,12,10,20]

# %%
plt.bar(x,y,color="g",align="center",width=0.5,edgecolor="red")
# Out:
# <BarContainer object of 5 artists>

# %%
ages=np.random.normal(20,2,1000)
plt.hist(ages)
# Out:
# (array([  7.,  45., 132., 212., 266., 211.,  82.,  41.,   3.,   1.]),
#  array([14.08624734, 15.45769024, 16.82913313, 18.20057603, 19.57201892,
#         20.94346182, 22.31490471, 23.68634761, 25.0577905 , 26.4292334 ,
#         27.80067629]),
#  <BarContainer object of 10 artists>)

# %%
x1=["Python","C++","C","JavaScript","Java"]
y1=[12,45,45,60,15]
explod=[0,0,0,0.1,0]
plt.pie(y1,labels=x1,explode=explod,autopct="%.2f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x2816548dbd0>,
# ...
#  [Text(1.0751437258359087, 0.23252089969652312, 'Python'),
#   Text(0.37316264219780176, 1.0347703331986067, 'C++'),
#   Text(-1.0443374006352077, 0.3454842885494181, 'C'),
#   Text(-0.031944682597632175, -1.1995747318336347, 'JavaScript'),
#   Text(1.0612446725774278, -0.28941275874782707, 'Java')],
#  [Text(0.5864420322741319, 0.12682958165264896, '6.78%'),
#   Text(0.20354325938061912, 0.5644201817446945, '25.42%'),
#   Text(-0.5696385821646587, 0.18844597557240986, '25.42%'),
#   Text(-0.018634398181952103, -0.6997519269029535, '33.90%'),
#   Text(0.5788607304967788, -0.15786150477154204, '8.47%')])

# %%
fst=np.linspace(0,10,25)
nd=np.linspace(10,200,25)
rd=np.linspace(200,210,25)
th=np.linspace(210,230,25)
data=np.concatenate((fst,nd,rd,th))
plt.boxplot(data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x28165506710>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x28165506990>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x281655065d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x28165506c10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x28165506d50>],
#  'means': []}
